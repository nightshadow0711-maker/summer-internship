# %%
print("hello world");
print("dhruv singh bisht");
name=("dhruv singh bisht ")
print(name.upper())
len(name)
# Out:
# hello world
# dhruv singh bisht
# DHRUV SINGH BISHT
# 18

# %%
name=("dhruv singh bisht");
add=("house 3 kalyanpur lucknow");
college=("SRMCEM");
print(name,add,college);
# Out:
# dhruv singh bisht house 3 kalyanpur lucknow SRMCEM

# %%
a=12;
b=34;
print(a+b);
print(a-b)
print(a**b)
print(a%b)
print(a/b,a*b,type(a/b))
# Out:
# 46
# -22
# 4922235242952026704037113243122008064
# 12
# 0.35294117647058826 408 <class 'float'>

# %%
name = input("enter your name")
print(name)
age=int(input("enter age"))
dept=input("enter dept")
print(age,dept)
# Out:
# enter your namedhruv
# dhruv
# enter age23
# enter deptsenior analyst
# 23 senior analyst

# %%
age=30
if age>21 or age==21:
  print("legal to drink")
# Out:
# legal to drink

# %%
marks=int(input("enter marks out of 500"))
rank=int(input("enter your rank"))
if marks>300 or rank<10000:
  print("eligible")
else:
  print("not eligible")
# Out:
# enter marks out of 500454
# enter your rank9879689
# eligible

# %%
age=int(input("enter age"))
if age>=60:
  print("senior citizen")
elif age>18 and age<60:
  print("adult")
else:
  print("child")
# Out:
# enter age34
# adult

# %%
marks=int(input("enter marks"))
if marks>=90:
  print("A")
elif marks>=80:
  print("B")
elif marks >= 50:
    print("c")
else:
  print("C")
# Out:
# enter marks33
# C

# %%
num=int(input("enter any no. -->"))
if num%5==0:
  print("divisible")
else:
  print ("not divisible")
# Out:
# enter any no. -->6545646
# not divisible

# %%
num=int(input("enter any no."))
if num%3==0:
  if num%5==0:
    print ("divisible by both")
  else:
    print("divisible by 3")
elif num%5==0:
  print("divisible by 5")
# Out:
# enter any no.55667

# %%
passs = "roro"
paas=input("enter correct code")
if passs==paas:
  print("access granted")
else:
  print("acess denied")
# Out:
# enter correct code8778
# acess denied

# %%
num=input("enter random no.")
a=len(num)
print("it is a " ,a ,"digit no.")
# Out:
# enter random no.6745647
# it is a  7 digit no.

# %%
num1=int(input("enter no."))
num2=int(input("enter no."))
operator=input("enter operator")
if operator=="+":
  print(num1+num2)
elif operator=="-":
  print(num1-num2)
elif operator=="*":
  print(num1*num2)
elif operator=="/":
  print(num1/num2)
elif operator=="%":
  print(num1%num2)
elif operator=="**":
  print(num1**num2)
else:
  print("wrong opreator1")
# Out:
# enter no.656757
# enter no.677467
# enter operator+
# 1334224

# %%
for i in range(1,9,1):
  print ("books")
# Out:
# books
# books
# books
# books
# books
# books
# books
# books

# %%
name="i love books"
print(name[2:6])
print (name[1:6:3])
print(name[9:1:-1])
# Out:
# love
#  v
# oob evol

# %%
num=(input("enter your no."))
num1=(num[::-1])
if num ==num1:
  print("palindrome")
else:
  print("non palindrome")
# Out:
# enter your no.8787
# non palindrome

# %%
name="harshit"
name1="Raj"
print("harshit  "*5)
print((name+" "+name1).upper())
print((name+" "+name1).lower())
print((name+" "+name1).title())
print((name+" "+name1).capitalize())
print(name.find("a"))
print(name.count("t"))
# Out:
# harshit  harshit  harshit  harshit  harshit
# HARSHIT RAJ
# harshit raj
# Harshit Raj
# Harshit raj
# 1
# 1

# %%
b=[200000,2000,20000]
a=[20,20,30,40,50]
print(a+b)
print(a[0]+6*2)
print(a[0:3:1])
b.sort()
print(b)
a.reverse()
print(a)
print (20 in a)
# Out:
# [20, 20, 30, 40, 50, 200000, 2000, 20000]
# 32
# [20, 20, 30]
# [2000, 20000, 200000]
# [50, 40, 30, 20, 20]
# True

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install notebook
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 46.7 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
marks=pd.Series([85,90,78,95])
print(marks)
# Out:
# 0    85
# 1    90
# 2    78
# 3    95
# dtype: int64

# %%
student={
    "name":["rahul","amit","priya"],
    "age":[20,21,19],
    "marks":[80,90,95],
}
df=pd.DataFrame(student)
print(df)
# Out:
#     name  age  marks
# 0  rahul   20     80
# 1   amit   21     90
# 2  priya   19     95

# %%
import pandas as pd
df=pd.read_csv('/content/Zomato-data-.csv')
df.tail(8)
df.sample(8)
df.head()
# Out:
#                     name online_order book_table   rate  votes  \
# 0                  Jalsa          Yes        Yes  4.1/5    775
# 1         Spice Elephant          Yes         No  4.1/5    787
# 2        San Churro Cafe          Yes         No  3.8/5    918
# 3  Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4          Grand Village           No         No  3.8/5    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
df.shape
# Out:
# (148, 7)

# %%
df.columns
# Out:
# Index(['name', 'online_order', 'book_table', 'rate', 'votes',
#        'approx_cost(for two people)', 'listed_in(type)'],
#       dtype='object')

# %%
df.dtypes
# Out:
# name                           object
# online_order                   object
# book_table                     object
# rate                           object
# votes                           int64
# approx_cost(for two people)     int64
# listed_in(type)                object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         148 non-null    object
#  1   online_order                 148 non-null    object
#  2   book_table                   148 non-null    object
#  3   rate                         148 non-null    object
#  4   votes                        148 non-null    int64
#  5   approx_cost(for two people)  148 non-null    int64
#  6   listed_in(type)              148 non-null    object
# dtypes: int64(2), object(5)
# memory usage: 8.2+ KB

# %%
df['approx_cost(for two people)'].describe()
# Out:
# count    148.000000
# mean     418.243243
# std      223.085098
# min      100.000000
# 25%      200.000000
# 50%      400.000000
# 75%      600.000000
# max      950.000000
# Name: approx_cost(for two people), dtype: float64

# %%
df["future_age"]=df["age"]+5
df.rename(columns={"Name":"Student"})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'age'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_2274/2597036045.py in <cell line: 0>()
# ----> 1 df["future_age"]=df["age"]+5
# ...

# %%
import pandas as pd

data = {
    "Emp_ID": [101,102,103,104,105,106,107,108,109,110],
    "Name": ["Aman","Neha","Rahul","Priya","Karan",
             "Simran","Mohit","Anjali","Vikas","Pooja"],
    "Age": [24,25,23,28,30,26,27,24,29,25],
    "Department": ["HR","IT","Sales","IT","HR",
                   "Finance","Sales","IT","Finance","HR"],
    "Salary": [35000,50000,45000,60000,38000,
               55000,47000,62000,58000,40000],
    "City": ["Delhi","Lucknow","Noida","Delhi","Jaipur",
             "Noida","Lucknow","Delhi","Jaipur","Delhi"]
}

df = pd.DataFrame(data)

print(df)
# Out:
#    Emp_ID    Name  Age Department  Salary     City
# 0     101    Aman   24         HR   35000    Delhi
# 1     102    Neha   25         IT   50000  Lucknow
# 2     103   Rahul   23      Sales   45000    Noida
# 3     104   Priya   28         IT   60000    Delhi
# 4     105   Karan   30         HR   38000   Jaipur
# 5     106  Simran   26    Finance   55000    Noida
# 6     107   Mohit   27      Sales   47000  Lucknow
# 7     108  Anjali   24         IT   62000    Delhi
# 8     109   Vikas   29    Finance   58000   Jaipur
# 9     110   Pooja   25         HR   40000    Delhi

# %%
df.head()
# Out:
#    Emp_ID   Name  Age Department  Salary     City
# 0     101   Aman   24         HR   35000    Delhi
# 1     102   Neha   25         IT   50000  Lucknow
# 2     103  Rahul   23      Sales   45000    Noida
# 3     104  Priya   28         IT   60000    Delhi
# 4     105  Karan   30         HR   38000   Jaipur

# %%
df.tail()
# Out:
#    Emp_ID    Name  Age Department  Salary     City
# 5     106  Simran   26    Finance   55000    Noida
# 6     107   Mohit   27      Sales   47000  Lucknow
# 7     108  Anjali   24         IT   62000    Delhi
# 8     109   Vikas   29    Finance   58000   Jaipur
# 9     110   Pooja   25         HR   40000    Delhi

# %%
df.sample()
# Out:
#    Emp_ID   Name  Age Department  Salary   City
# 9     110  Pooja   25         HR   40000  Delhi

# %%
df.shape
# Out:
# (10, 6)

# %%
df.columns
# Out:
# Index(['Emp_ID', 'Name', 'Age', 'Department', 'Salary', 'City'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Emp_ID      10 non-null     int64
#  1   Emp_name    10 non-null     object
#  2   Age         10 non-null     int64
#  3   Department  10 non-null     object
#  4   Salary      10 non-null     int64
#  5   City        10 non-null     object
#  6   Bonus       10 non-null     float64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 692.0+ bytes

# %%
df.dtypes
# Out:
# Emp_ID         int64
# Name          object
# Age            int64
# Department    object
# Salary         int64
# City          object
# dtype: object

# %%
df["Salary"].max()
df["Name"].count()
# Out:
# np.int64(10)

# %%
df["Department"].unique()
# Out:
# array(['HR', 'IT', 'Sales', 'Finance'], dtype=object)

# %%
df["Department"].unique()
# Out:
# array(['HR', 'IT', 'Sales', 'Finance'], dtype=object)

# %%
df["Bonus"]=df["Salary"]*0.5
print(df)
# Out:
#    Emp_ID    Name  Age Department  Salary     City    Bonus
# 0     101    Aman   24         HR   35000    Delhi  17500.0
# 1     102    Neha   25         IT   50000  Lucknow  25000.0
# 2     103   Rahul   23      Sales   45000    Noida  22500.0
# 3     104   Priya   28         IT   60000    Delhi  30000.0
# 4     105   Karan   30         HR   38000   Jaipur  19000.0
# 5     106  Simran   26    Finance   55000    Noida  27500.0
# 6     107   Mohit   27      Sales   47000  Lucknow  23500.0
# 7     108  Anjali   24         IT   62000    Delhi  31000.0
# 8     109   Vikas   29    Finance   58000   Jaipur  29000.0
# 9     110   Pooja   25         HR   40000    Delhi  20000.0

# %%
df.rename(columns={"Name":"Emp_name"},inplace=True)
print(df)
# Out:
#    Emp_ID Emp_name  Age Department  Salary     City    Bonus
# 0     101     Aman   24         HR   35000    Delhi  17500.0
# 1     102     Neha   25         IT   50000  Lucknow  25000.0
# 2     103    Rahul   23      Sales   45000    Noida  22500.0
# 3     104    Priya   28         IT   60000    Delhi  30000.0
# 4     105    Karan   30         HR   38000   Jaipur  19000.0
# 5     106   Simran   26    Finance   55000    Noida  27500.0
# 6     107    Mohit   27      Sales   47000  Lucknow  23500.0
# 7     108   Anjali   24         IT   62000    Delhi  31000.0
# 8     109    Vikas   29    Finance   58000   Jaipur  29000.0
# 9     110    Pooja   25         HR   40000    Delhi  20000.0

# %%
df.drop("Bonus",axis=1,inplace=True)
print(df)
# Out:
#    Emp_ID Emp_name  Age Department  Salary     City
# 0     101     Aman   24         HR   35000    Delhi
# 1     102     Neha   25         IT   50000  Lucknow
# 2     103    Rahul   23      Sales   45000    Noida
# 3     104    Priya   28         IT   60000    Delhi
# 4     105    Karan   30         HR   38000   Jaipur
# 5     106   Simran   26    Finance   55000    Noida
# 6     107    Mohit   27      Sales   47000  Lucknow
# 7     108   Anjali   24         IT   62000    Delhi
# 8     109    Vikas   29    Finance   58000   Jaipur
# 9     110    Pooja   25         HR   40000    Delhi

# %% [markdown]
# axis

# %%
df.isnull()
# Out:
#    Emp_ID  Emp_name    Age  Department  Salary   City
# 0   False     False  False       False   False  False
# 1   False     False  False       False   False  False
# 2   False     False  False       False   False  False
# 3   False     False  False       False   False  False
# 4   False     False  False       False   False  False
# 5   False     False  False       False   False  False
# 6   False     False  False       False   False  False
# 7   False     False  False       False   False  False
# 8   False     False  False       False   False  False
# 9   False     False  False       False   False  False

# %%
df.isnull().sum()
# Out:
# Emp_ID        0
# Emp_name      0
# Age           0
# Department    0
# Salary        0
# City          0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["Emp_name"].isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# Name: Emp_name, dtype: bool

# %%
df[df["City"]=="Delhi"]
# Out:
#    Emp_ID Emp_name  Age Department  Salary   City
# 0     101     Aman   24         HR   35000  Delhi
# 3     104    Priya   28         IT   60000  Delhi
# 7     108   Anjali   24         IT   62000  Delhi
# 9     110    Pooja   25         HR   40000  Delhi

# %%
import pandas as pd

data = {
    "Student_ID": [101,102,103,104,105,106,107,108,109,110,111,112,113,114,115,116,117,118,119,120],

    "Name": ["Aman","Neha","Rahul","Priya","Karan","Simran","Mohit","Anjali","Vikas","Pooja","Rohit","Sneha","Arjun","Riya","Deepak","Muskan","Yash","Komal","Abhishek","Nisha"],

    "Gender": ["Male","Female","Male","Female","Male","Female","Male","Female","Male","Female","Male","Female","Male","Female","Male","Female","Male","Female","Male","Female"],

    "Age": [20,21,19,22,20,21,20,19,22,20,21,20,23,19,22,20,21,22,20,19],

    "Department": ["CSE","IT","ECE","CSE","IT","CSE","ECE","IT","CSE","ECE","IT","CSE","ECE","IT","CSE","ECE","IT","CSE","ECE","IT"],

    "Semester": [4,4,2,6,4,6,2,4,8,6,2,8,6,4,8,2,6,4,8,2],

    "Marks": [85,92,78,95,67,88,72,91,81,76,69,94,73,89,97,66,82,90,79,84],

    "Attendance": [92,95,85,97,78,90,82,98,88,84,80,96,83,91,99,76,89,94,87,92],"CGPA": [8.5,9.2,7.8,9.5,6.9,8.8,7.2,9.1,8.1,7.6,7.0,9.4,7.4,8.9,9.8,6.8,8.2,9.0,7.9,8.4],"City": ["Delhi","Lucknow","Noida","Jaipur","Delhi","Noida","Lucknow","Delhi","Jaipur","Delhi","Noida","Lucknow","Delhi","Jaipur","Delhi","Noida","Lucknow","Delhi","Jaipur","Delhi"]
}

df = pd.DataFrame(data)

# %%
print(df)
# Out:
#     Student_ID      Name  Gender  Age Department  Semester  Marks  Attendance  \
# 0          101      Aman    Male   20        CSE         4     85          92
# 1          102      Neha  Female   21         IT         4     92          95
# 2          103     Rahul    Male   19        ECE         2     78          85
# 3          104     Priya  Female   22        CSE         6     95          97
# 4          105     Karan    Male   20         IT         4     67          78
# 5          106    Simran  Female   21        CSE         6     88          90
# 6          107     Mohit    Male   20        ECE         2     72          82
# 7          108    Anjali  Female   19         IT         4     91          98
# 8          109     Vikas    Male   22        CSE         8     81          88
# 9          110     Pooja  Female   20        ECE         6     76          84
# 10         111     Rohit    Male   21         IT         2     69          80
# ...
